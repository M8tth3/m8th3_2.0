# %% [raw]
# ---
# comments: true
# layout: post
# title: MCQ 2020 Frequently Missed Questions
# description: Questions and sample Python code to represent the most frequently missed questions on the 2020 AP Computer Science A Multiple Choice Exam.
# type: tangibles
# courses: { compsci: {week: 14} }
# ---

# %% [markdown]
# ## 4. Cause of overflow Error (1D, binary math) - Tara Sehdave
#
# In a certain computer program, two positive integers are added together, resulting in an overflow error. Which of the following best explains why the error occurs?
#
# Responses
# A
# The program attempted to perform an operation that is considered an undecidable problem.
#
# B
# The precision of the result is limited due to the constraints of using a floating-point representation.
#
# C
# The program can only use a fixed number of bits to represent integers; the computed sum is greater than the maximum representable value.
#
# D
# The program cannot represent integers; the integers are converted into decimal approximations, leading to rounding errors.
#
# The correct answer is C because...
#
# - Overflow error occurs in a computer program when adding two positive integers.
# - The program uses a fixed number of bits to represent integers.
# - The sum of the two integers exceeds the maximum representable value within the fixed number of bits.
# - Due to this limitation, the program cannot accurately represent the result of the addition.
# - As a result, an overflow error is triggered to indicate that the computed sum is beyond the representable range.

# %%
# python overflow example
# as a popcorn hack (binary challenge), describe an overflow in 8 binary digits
# Add 1 to 11111111 (255)
# Subtract 1 from 00000000 (0)
# Try overflow and underflow here: https://nighthawkcoders.github.io/teacher_portfolio/c4.4/2023/09/14/javascript-binary-U2-1.html

import math

print(math.exp(1000))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /tmp/ipykernel_3752/365049520.py in <module>
#       7 import math
#       8
# ----> 9 print(math.exp(1000))
#
# OverflowError: math range error

# %% [markdown]
# ## 5. Inputs to Logic Circuit (2D, binary logic) - Hanlun Li
#
# The diagram below shows a circuit composed of three logic gates. Each gate takes two inputs and produces a single output. For which of the following input values will the circuit have an output of true ?

# %% [markdown]
# The diagram in question shows a circuit composed of three logic gates. Each gate takes two inputs and produces a single output. <br>
#
# For which of the following input values will the circuit have an output of true ? <br>
#
# A) A = true,  B = true,  C = true,  D = false <br>
# B) A = true,  B = false, C = false, D = true <br>
# C) A = false, B = true,  C = true,  D = true <br>
# D) A = false, B = false, C = true,  D = true <br>
#
# A OR B = True, C AND D = True, and since True AND True = True, C is correct. <br>
# OR gate only returns true if one of the values is true, and the AND gate returns true if both values are true.

# %%
# represent gates and circuits
# as a popcorn hack (coding challenge), create multiple new circuits and gates
# NOT, NAND, NOR, XOR, XNOR
# Create a hypothetical circuit, such as burglar alarm, decision tree for autonomous car, etc.

# OR gate
def OR_gate(A, B):
    return A or B

# AND gate
def AND_gate(A, B):
    return A and B

# NOT gate
def NOT_gate(A):
    return not A

# Theoretical circuit representing a Car starting
# A and B could be security checks, such as key being inserted or a fob being present
# C and D could be operational checks, such as a start button being pressed and safety belt being fastened
# The enclosing AND gate ensures car only operates when both security and operational checks are met
def car_start_circuit(A, B, C, D):
    security_check = OR_gate(A, B)  # At least one security measure passed
    operational_check = AND_gate(C, D)  # All operational checks passed
    return AND_gate(security_check, operational_check)

# Print truth table for circuit
print('Key Inserted', 'Fob', 'Start Button Pressed', 'Safety Belt', "-->", 'Output')

# Nested loops for generating all possible combinations of inputs
for A in [False, True]:
    for B in [False, True]:
        for C in [False, True]:
            for D in [False, True]:
                print(A, B, C, D, "-->", car_start_circuit(A, B, C, D))
# Out:
# Key Inserted Fob Start Button Pressed Safety Belt --> Output
# False False False False --> False
# False False False True --> False
# False False True False --> False
# False False True True --> False
# False True False False --> False
# False True False True --> False
# False True True False --> False
# False True True True --> True
# True False False False --> False
# True False False True --> False
# True False True False --> False
# True False True True --> True
# True True False False --> False
# True True False True --> False
# True True True False --> False
# True True True True --> True

# %% [markdown]
# ## 11. Color represented by binary Triplet (2D, binary) - Torin Wolff
#
# A color in a computing application is represented by an RGB triplet that describes the amount of red, green, and blue, respectively, used to create the desired color. A selection of colors and their corresponding RGB triplets are shown in the following table. Each value is represented in decimal (base 10).
#
# According to information in the table, what color is represented by the binary RGB triplet (11111111, 11111111, 11110000) ?
#
# #### What is a binary triplet?
# A binary triplet is a set of three binary numbers. Binary numbers are numbers that are represented by a series of 1's and 0's. Binary numbers are used in computers because they are easy to represent with electrical signals. A binary triplet is a set of three binary numbers that are used to represent a color. The first number represents the amount of red in the color, the second number represents the amount of green in the color, and the third number represents the amount of blue in the color. The numbers are represented in binary because it is easy to represent with electrical signals. The numbers are represented in a triplet because it is easy to represent with electrical signals.
#
# #### How is a color in binary represented?
# A color in binary is represented by a set of three binary numbers. The first number represents the amount of red in the color, the second number represents the amount of green in the color, and the third number represents the amount of blue in the color. The numbers are represented in binary because it is easy to represent with electrical signals. The numbers are represented in a triplet because it is easy to represent with electrical signals. An example of this would be: (01101110, 11111111, 10010110), if you converted this binary triplet to a decimal number it would be 110, 255, 150. This would be a shade of the color green.
#
# #### How do you convert a binary triplet to a decimal number?
# To convert a binary string to a decimal number you need to multiply each digit by its place value. For example, if you have the binary string 1010 you would multiply the first digit by 2^3, the second digit by 2^2, the third digit by 2^1, and the fourth digit by 2^0. This would give you the decimal number 10. To convert a binary triplet to a decimal number you need to multiply each digit by its place value. For example, if you have the binary triplet (01101110, 11111111, 10010110) you would multiply the first digit by 2^7, the second digit by 2^6, the third digit by 2^5, the fourth digit by 2^4, the fifth digit by 2^3, the sixth digit by 2^2, the seventh digit by 2^1, and the eighth digit by 2^0. This would give you the decimal number 110, 255, 150.
#
# (0 * 2^7) + (1 * 2^6) + (1 * 2^5) + (0 * 2^4) + (1 * 2^3) + (1 * 2^2) + (1 * 2^1) + (0 * 2^0)
#
# = 0 + 64 + 32 + 0 + 8 + 4 + 2 + 0
#
# = 110
#
# (insert photo)

# %%
# Convert binary RGB triplet to decimal
# as a hack (binary challenge), make the rgb standard colors
# as a 2nd hack, make your favorite color pattern 

import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Function to convert binary to decimal
def binary_to_decimal(binary):
    return int(binary, 2)

def plot_colors(rgb_triplets):
    # Create a figure with one subplot per RGB triplet
    fig, axs = plt.subplots(1, len(rgb_triplets), figsize=(2 * len(rgb_triplets), 2))
    
    # Ensure axs is always a list
    axs = axs if len(rgb_triplets) > 1 else [axs]

    for ax, (red_binary, green_binary, blue_binary) in zip(axs, rgb_triplets):
        # Convert to binary strings to decimal
        red_decimal = binary_to_decimal(red_binary)
        green_decimal = binary_to_decimal(green_binary)
        blue_decimal = binary_to_decimal(blue_binary)

        # Normalize number to [0, 1] range, as it is expected by matplotlib 
        red, green, blue = red_decimal/255, green_decimal/255, blue_decimal/255

        # Define a rectangle patch with the binary RGB triplet color and a black border
        rect = patches.Rectangle((0, 0), 1, 1, facecolor=(red, green, blue), edgecolor='black', linewidth=2)
        
        # Add the rectangle to the plot which shows the color 
        ax.add_patch(rect)

        # Remove axis information, we just want to see the color
        ax.axis('off')

        # Print the binary and decimal values
        print("binary:", red_binary, green_binary, blue_binary)    
        print("decimal", red_decimal, green_decimal, blue_decimal)
        print("proportion", red, green, blue)

    # Show the colors
    plt.show()

# Test the function with a list of RGB triplets
rgb_triplet = [('11010101', '11101101 ', '11111100')] # College Board example
plot_colors(rgb_triplet)

rgb_primary = [('11111111', '00000000', '00000000'), 
                ('11111111', '11111111', '00000000'),
                ('00000000', '00000000', '11111111')]
plot_colors(rgb_primary)
# Out:
# binary: 11010101 11101101  11111100
# decimal 213 237 252
# proportion 0.8352941176470589 0.9294117647058824 0.9882352941176471
# binary: 11111111 00000000 00000000
# decimal 255 0 0
# proportion 1.0 0.0 0.0
# binary: 11111111 11111111 00000000
# decimal 255 255 0
# proportion 1.0 1.0 0.0
# binary: 00000000 00000000 11111111
# decimal 0 0 255
# proportion 0.0 0.0 1.0

# %% [markdown]
# ## 50. Reasonable time algorithms (1D, Big O) - Vance Reynolds
#
# Consider the following algorithms. Each algorithm operates on a list containing n elements, where n is a very large integer.
#
# - An algorithm that accesses each element in the list twice
# - An algorithm that accesses each element in the list n times
# - An algorithm that accesses only the first 10 elements in the list, regardless of the size of the list
#
#
# Which of the algorithms run in reasonable time?
# Answer D is correct because in order for an algorithm to run in reasonable time, it must take a number of steps less than or equal to a polynomial function.
#
# - Algorithm I accesses elements times (twice for each of n elements), which is considered in time.
# - Algorithm II accesses elements (n times for each of n elements), which is in reasonable time.
# - Algorithm III accesses 10 elements, which is in reasonable time.
#
# Simple Explainations:
#
# Unreasonable time: Algorithms with exponential or factorial efficiencies are examples of algorithms that run in an unreasonable amount of time.
#
# Reasonable time: Algorithms with a polynomial efficiency or lower (constant, linear, square, cube, etc.) are said to run in a reasonable amount of time.

# %%
# Big O notation example algorithms
# as a popcorn hack (coding challenge), scale list of size by factor of 10 and measure the times
# what do you think about college board's notion of reasonable time for an algorithm?
# as a 2nd hack, create a slow algorithm and measure its time, which are considered slow algorithms... 
#   O(n^3) which is three nested loops 
#   O(2^n) which is a recursive algorithm with two recursive calls

import time

# O(n) Algorithm that accesses each element in the list twice, 2 * n times 
def algorithm_2n(lst):
    for i in lst:
        pass
    for i in lst:
        pass

# O(n^2) Algorithm that accesses each element in the list n times, n * n times
def algorithm_nSquared(lst):
    for i in lst:
        for j in lst:
            pass

# O(1) Algorithm that accesses only the first 10 elements in the list, 10 * 1 is constant 
def algorithm_10times(lst):
    for i in lst[:10]:
        pass

# Create a large list
n = 10000
lst = list(range(n))

# Measure the time taken by algorithm1
start = time.time()
algorithm_2n(lst)
end = time.time()
print(f"Algorithm 2 * N took {(end - start)*1000:.2f} milliseconds")

# Measure the time taken by algorithm2
start = time.time()
algorithm_nSquared(lst)
end = time.time()
print(f"Algorithm N^2 took {(end - start)*1000:.2f} milliseconds")

# Measure the time taken by algorithm3
start = time.time()
algorithm_10times(lst)
end = time.time()
print(f"Algorithm 10 times took {(end - start)*1000:.2f} milliseconds")
# Out:
# Algorithm 2 * N took 0.12 milliseconds
# Algorithm N^2 took 454.01 milliseconds
# Algorithm 10 times took 0.04 milliseconds

# %%
# Popcorn Hack 2 (Slow Algorithm)

def pizza(ingredients):
    for dough in ingredients:
        for sauce in ingredients:
            for cheese in ingredients:
                for topping in ingredients:
                    print(f"Pizza with: {dough}, {sauce}, {cheese}, {topping}")
#O(n^4)
ingredients = ["thin crust", "thick crust", "tomato sauce", "white sauce", "mozzarella", "cheddar", "pepperoni", "mushrooms", "onions"]
start = time.time()
pizza(ingredients)
end = time.time()
print(f"Algorithm 10 times took {(end - start)*1000:.2f} milliseconds")
# Out:
# Pizza with: thin crust, thin crust, thin crust, thin crust
# Pizza with: thin crust, thin crust, thin crust, thick crust
# Pizza with: thin crust, thin crust, thin crust, tomato sauce
# Pizza with: thin crust, thin crust, thin crust, white sauce
# Pizza with: thin crust, thin crust, thin crust, mozzarella
# Pizza with: thin crust, thin crust, thin crust, cheddar
# Pizza with: thin crust, thin crust, thin crust, pepperoni
# Pizza with: thin crust, thin crust, thin crust, mushrooms
# Pizza with: thin crust, thin crust, thin crust, onions
# Pizza with: thin crust, thin crust, thick crust, thin crust
# Pizza with: thin crust, thin crust, thick crust, thick crust
# Pizza with: thin crust, thin crust, thick crust, tomato sauce
# Pizza with: thin crust, thin crust, thick crust, white sauce
# Pizza with: thin crust, thin crust, thick crust, mozzarella
# Pizza with: thin crust, thin crust, thick crust, cheddar
# Pizza with: thin crust, thin crust, thick crust, pepperoni
# Pizza with: thin crust, thin crust, thick crust, mushrooms
# Pizza with: thin crust, thin crust, thick crust, onions
# Pizza with: thin crust, thin crust, tomato sauce, thin crust
# Pizza with: thin crust, thin crust, tomato sauce, thick crust
# Pizza with: thin crust, thin crust, tomato sauce, tomato sauce
# Pizza with: thin crust, thin crust, tomato sauce, white sauce
# Pizza with: thin crust, thin crust, tomato sauce, mozzarella
# Pizza with: thin crust, thin crust, tomato sauce, cheddar
# Pizza with: thin crust, thin crust, tomato sauce, pepperoni
# Pizza with: thin crust, thin crust, tomato sauce, mushrooms
# Pizza with: thin crust, thin crust, tomato sauce, onions
# Pizza with: thin crust, thin crust, white sauce, thin crust
# Pizza with: thin crust, thin crust, white sauce, thick crust
# Pizza with: thin crust, thin crust, white sauce, tomato sauce
# Pizza with: thin crust, thin crust, white sauce, white sauce
# Pizza with: thin crust, thin crust, white sauce, mozzarella
# Pizza with: thin crust, thin crust, white sauce, cheddar
# Pizza with: thin crust, thin crust, white sauce, pepperoni
# Pizza with: thin crust, thin crust, white sauce, mushrooms
# Pizza with: thin crust, thin crust, white sauce, onions
# Pizza with: thin crust, thin crust, mozzarella, thin crust
# Pizza with: thin crust, thin crust, mozzarella, thick crust
# Pizza with: thin crust, thin crust, mozzarella, tomato sauce
# Pizza with: thin crust, thin crust, mozzarella, white sauce
# Pizza with: thin crust, thin crust, mozzarella, mozzarella
# Pizza with: thin crust, thin crust, mozzarella, cheddar
# Pizza with: thin crust, thin crust, mozzarella, pepperoni
# Pizza with: thin crust, thin crust, mozzarella, mushrooms
# Pizza with: thin crust, thin crust, mozzarella, onions
# Pizza with: thin crust, thin crust, cheddar, thin crust
# Pizza with: thin crust, thin crust, cheddar, thick crust
# Pizza with: thin crust, thin crust, cheddar, tomato sauce
# Pizza with: thin crust, thin crust, cheddar, white sauce
# Pizza with: thin crust, thin crust, cheddar, mozzarella
# Pizza with: thin crust, thin crust, cheddar, cheddar
# Pizza with: thin crust, thin crust, cheddar, pepperoni
# Pizza with: thin crust, thin crust, cheddar, mushrooms
# Pizza with: thin crust, thin crust, cheddar, onions
# Pizza with: thin crust, thin crust, pepperoni, thin crust
# Pizza with: thin crust, thin crust, pepperoni, thick crust
# Pizza with: thin crust, thin crust, pepperoni, tomato sauce
# Pizza with: thin crust, thin crust, pepperoni, white sauce
# Pizza with: thin crust, thin crust, pepperoni, mozzarella
# Pizza with: thin crust, thin crust, pepperoni, cheddar
# Pizza with: thin crust, thin crust, pepperoni, pepperoni
# Pizza with: thin crust, thin crust, pepperoni, mushrooms
# Pizza with: thin crust, thin crust, pepperoni, onions
# Pizza with: thin crust, thin crust, mushrooms, thin crust
# Pizza with: thin crust, thin crust, mushrooms, thick crust
# Pizza with: thin crust, thin crust, mushrooms, tomato sauce
# Pizza with: thin crust, thin crust, mushrooms, white sauce
# Pizza with: thin crust, thin crust, mushrooms, mozzarella
# Pizza with: thin crust, thin crust, mushrooms, cheddar
# Pizza with: thin crust, thin crust, mushrooms, pepperoni
# Pizza with: thin crust, thin crust, mushrooms, mushrooms
# Pizza with: thin crust, thin crust, mushrooms, onions
# Pizza with: thin crust, thin crust, onions, thin crust
# Pizza with: thin crust, thin crust, onions, thick crust
# Pizza with: thin crust, thin crust, onions, tomato sauce
# Pizza with: thin crust, thin crust, onions, white sauce
# Pizza with: thin crust, thin crust, onions, mozzarella
# Pizza with: thin crust, thin crust, onions, cheddar
# Pizza with: thin crust, thin crust, onions, pepperoni
# Pizza with: thin crust, thin crust, onions, mushrooms
# Pizza with: thin crust, thin crust, onions, onions
# Pizza with: thin crust, thick crust, thin crust, thin crust
# Pizza with: thin crust, thick crust, thin crust, thick crust
# Pizza with: thin crust, thick crust, thin crust, tomato sauce
# Pizza with: thin crust, thick crust, thin crust, white sauce
# Pizza with: thin crust, thick crust, thin crust, mozzarella
# Pizza with: thin crust, thick crust, thin crust, cheddar
# Pizza with: thin crust, thick crust, thin crust, pepperoni
# Pizza with: thin crust, thick crust, thin crust, mushrooms
# Pizza with: thin crust, thick crust, thin crust, onions
# Pizza with: thin crust, thick crust, thick crust, thin crust
# Pizza with: thin crust, thick crust, thick crust, thick crust
# Pizza with: thin crust, thick crust, thick crust, tomato sauce
# Pizza with: thin crust, thick crust, thick crust, white sauce
# Pizza with: thin crust, thick crust, thick crust, mozzarella
# Pizza with: thin crust, thick crust, thick crust, cheddar
# Pizza with: thin crust, thick crust, thick crust, pepperoni
# Pizza with: thin crust, thick crust, thick crust, mushrooms
# Pizza with: thin crust, thick crust, thick crust, onions
# Pizza with: thin crust, thick crust, tomato sauce, thin crust
# Pizza with: thin crust, thick crust, tomato sauce, thick crust
# Pizza with: thin crust, thick crust, tomato sauce, tomato sauce
# Pizza with: thin crust, thick crust, tomato sauce, white sauce
# Pizza with: thin crust, thick crust, tomato sauce, mozzarella
# Pizza with: thin crust, thick crust, tomato sauce, cheddar
# Pizza with: thin crust, thick crust, tomato sauce, pepperoni
# Pizza with: thin crust, thick crust, tomato sauce, mushrooms
# Pizza with: thin crust, thick crust, tomato sauce, onions
# Pizza with: thin crust, thick crust, white sauce, thin crust
# Pizza with: thin crust, thick crust, white sauce, thick crust
# Pizza with: thin crust, thick crust, white sauce, tomato sauce
# Pizza with: thin crust, thick crust, white sauce, white sauce
# Pizza with: thin crust, thick crust, white sauce, mozzarella
# Pizza with: thin crust, thick crust, white sauce, cheddar
# Pizza with: thin crust, thick crust, white sauce, pepperoni
# Pizza with: thin crust, thick crust, white sauce, mushrooms
# Pizza with: thin crust, thick crust, white sauce, onions
# Pizza with: thin crust, thick crust, mozzarella, thin crust
# Pizza with: thin crust, thick crust, mozzarella, thick crust
# Pizza with: thin crust, thick crust, mozzarella, tomato sauce
# Pizza with: thin crust, thick crust, mozzarella, white sauce
# Pizza with: thin crust, thick crust, mozzarella, mozzarella
# Pizza with: thin crust, thick crust, mozzarella, cheddar
# Pizza with: thin crust, thick crust, mozzarella, pepperoni
# Pizza with: thin crust, thick crust, mozzarella, mushrooms
# Pizza with: thin crust, thick crust, mozzarella, onions
# Pizza with: thin crust, thick crust, cheddar, thin crust
# Pizza with: thin crust, thick crust, cheddar, thick crust
# Pizza with: thin crust, thick crust, cheddar, tomato sauce
# Pizza with: thin crust, thick crust, cheddar, white sauce
# Pizza with: thin crust, thick crust, cheddar, mozzarella
# Pizza with: thin crust, thick crust, cheddar, cheddar
# Pizza with: thin crust, thick crust, cheddar, pepperoni
# Pizza with: thin crust, thick crust, cheddar, mushrooms
# Pizza with: thin crust, thick crust, cheddar, onions
# Pizza with: thin crust, thick crust, pepperoni, thin crust
# Pizza with: thin crust, thick crust, pepperoni, thick crust
# Pizza with: thin crust, thick crust, pepperoni, tomato sauce
# Pizza with: thin crust, thick crust, pepperoni, white sauce
# Pizza with: thin crust, thick crust, pepperoni, mozzarella
# Pizza with: thin crust, thick crust, pepperoni, cheddar
# Pizza with: thin crust, thick crust, pepperoni, pepperoni
# Pizza with: thin crust, thick crust, pepperoni, mushrooms
# Pizza with: thin crust, thick crust, pepperoni, onions
# Pizza with: thin crust, thick crust, mushrooms, thin crust
# Pizza with: thin crust, thick crust, mushrooms, thick crust
# Pizza with: thin crust, thick crust, mushrooms, tomato sauce
# Pizza with: thin crust, thick crust, mushrooms, white sauce
# Pizza with: thin crust, thick crust, mushrooms, mozzarella
# Pizza with: thin crust, thick crust, mushrooms, cheddar
# Pizza with: thin crust, thick crust, mushrooms, pepperoni
# Pizza with: thin crust, thick crust, mushrooms, mushrooms
# Pizza with: thin crust, thick crust, mushrooms, onions
# Pizza with: thin crust, thick crust, onions, thin crust
# Pizza with: thin crust, thick crust, onions, thick crust
# Pizza with: thin crust, thick crust, onions, tomato sauce
# Pizza with: thin crust, thick crust, onions, white sauce
# Pizza with: thin crust, thick crust, onions, mozzarella
# Pizza with: thin crust, thick crust, onions, cheddar
# Pizza with: thin crust, thick crust, onions, pepperoni
# Pizza with: thin crust, thick crust, onions, mushrooms
# Pizza with: thin crust, thick crust, onions, onions
# Pizza with: thin crust, tomato sauce, thin crust, thin crust
# Pizza with: thin crust, tomato sauce, thin crust, thick crust
# Pizza with: thin crust, tomato sauce, thin crust, tomato sauce
# Pizza with: thin crust, tomato sauce, thin crust, white sauce
# Pizza with: thin crust, tomato sauce, thin crust, mozzarella
# Pizza with: thin crust, tomato sauce, thin crust, cheddar
# Pizza with: thin crust, tomato sauce, thin crust, pepperoni
# Pizza with: thin crust, tomato sauce, thin crust, mushrooms
# Pizza with: thin crust, tomato sauce, thin crust, onions
# Pizza with: thin crust, tomato sauce, thick crust, thin crust
# Pizza with: thin crust, tomato sauce, thick crust, thick crust
# Pizza with: thin crust, tomato sauce, thick crust, tomato sauce
# Pizza with: thin crust, tomato sauce, thick crust, white sauce
# Pizza with: thin crust, tomato sauce, thick crust, mozzarella
# Pizza with: thin crust, tomato sauce, thick crust, cheddar
# Pizza with: thin crust, tomato sauce, thick crust, pepperoni
# Pizza with: thin crust, tomato sauce, thick crust, mushrooms
# Pizza with: thin crust, tomato sauce, thick crust, onions
# Pizza with: thin crust, tomato sauce, tomato sauce, thin crust
# Pizza with: thin crust, tomato sauce, tomato sauce, thick crust
# Pizza with: thin crust, tomato sauce, tomato sauce, tomato sauce
# Pizza with: thin crust, tomato sauce, tomato sauce, white sauce
# Pizza with: thin crust, tomato sauce, tomato sauce, mozzarella
# Pizza with: thin crust, tomato sauce, tomato sauce, cheddar
# Pizza with: thin crust, tomato sauce, tomato sauce, pepperoni
# Pizza with: thin crust, tomato sauce, tomato sauce, mushrooms
# Pizza with: thin crust, tomato sauce, tomato sauce, onions
# Pizza with: thin crust, tomato sauce, white sauce, thin crust
# Pizza with: thin crust, tomato sauce, white sauce, thick crust
# Pizza with: thin crust, tomato sauce, white sauce, tomato sauce
# Pizza with: thin crust, tomato sauce, white sauce, white sauce
# Pizza with: thin crust, tomato sauce, white sauce, mozzarella
# Pizza with: thin crust, tomato sauce, white sauce, cheddar
# Pizza with: thin crust, tomato sauce, white sauce, pepperoni
# Pizza with: thin crust, tomato sauce, white sauce, mushrooms
# Pizza with: thin crust, tomato sauce, white sauce, onions
# Pizza with: thin crust, tomato sauce, mozzarella, thin crust
# Pizza with: thin crust, tomato sauce, mozzarella, thick crust
# Pizza with: thin crust, tomato sauce, mozzarella, tomato sauce
# Pizza with: thin crust, tomato sauce, mozzarella, white sauce
# Pizza with: thin crust, tomato sauce, mozzarella, mozzarella
# Pizza with: thin crust, tomato sauce, mozzarella, cheddar
# Pizza with: thin crust, tomato sauce, mozzarella, pepperoni
# Pizza with: thin crust, tomato sauce, mozzarella, mushrooms
# Pizza with: thin crust, tomato sauce, mozzarella, onions
# Pizza with: thin crust, tomato sauce, cheddar, thin crust
# Pizza with: thin crust, tomato sauce, cheddar, thick crust
# Pizza with: thin crust, tomato sauce, cheddar, tomato sauce
# Pizza with: thin crust, tomato sauce, cheddar, white sauce
# Pizza with: thin crust, tomato sauce, cheddar, mozzarella
# Pizza with: thin crust, tomato sauce, cheddar, cheddar
# Pizza with: thin crust, tomato sauce, cheddar, pepperoni
# Pizza with: thin crust, tomato sauce, cheddar, mushrooms
# Pizza with: thin crust, tomato sauce, cheddar, onions
# Pizza with: thin crust, tomato sauce, pepperoni, thin crust
# Pizza with: thin crust, tomato sauce, pepperoni, thick crust
# Pizza with: thin crust, tomato sauce, pepperoni, tomato sauce
# Pizza with: thin crust, tomato sauce, pepperoni, white sauce
# Pizza with: thin crust, tomato sauce, pepperoni, mozzarella
# Pizza with: thin crust, tomato sauce, pepperoni, cheddar
# Pizza with: thin crust, tomato sauce, pepperoni, pepperoni
# Pizza with: thin crust, tomato sauce, pepperoni, mushrooms
# Pizza with: thin crust, tomato sauce, pepperoni, onions
# Pizza with: thin crust, tomato sauce, mushrooms, thin crust
# Pizza with: thin crust, tomato sauce, mushrooms, thick crust
# Pizza with: thin crust, tomato sauce, mushrooms, tomato sauce
# Pizza with: thin crust, tomato sauce, mushrooms, white sauce
# Pizza with: thin crust, tomato sauce, mushrooms, mozzarella
# Pizza with: thin crust, tomato sauce, mushrooms, cheddar
# Pizza with: thin crust, tomato sauce, mushrooms, pepperoni
# Pizza with: thin crust, tomato sauce, mushrooms, mushrooms
# Pizza with: thin crust, tomato sauce, mushrooms, onions
# Pizza with: thin crust, tomato sauce, onions, thin crust
# Pizza with: thin crust, tomato sauce, onions, thick crust
# Pizza with: thin crust, tomato sauce, onions, tomato sauce
# Pizza with: thin crust, tomato sauce, onions, white sauce
# Pizza with: thin crust, tomato sauce, onions, mozzarella
# Pizza with: thin crust, tomato sauce, onions, cheddar
# Pizza with: thin crust, tomato sauce, onions, pepperoni
# Pizza with: thin crust, tomato sauce, onions, mushrooms
# Pizza with: thin crust, tomato sauce, onions, onions
# Pizza with: thin crust, white sauce, thin crust, thin crust
# Pizza with: thin crust, white sauce, thin crust, thick crust
# Pizza with: thin crust, white sauce, thin crust, tomato sauce
# Pizza with: thin crust, white sauce, thin crust, white sauce
# Pizza with: thin crust, white sauce, thin crust, mozzarella
# Pizza with: thin crust, white sauce, thin crust, cheddar
# Pizza with: thin crust, white sauce, thin crust, pepperoni
# Pizza with: thin crust, white sauce, thin crust, mushrooms
# Pizza with: thin crust, white sauce, thin crust, onions
# Pizza with: thin crust, white sauce, thick crust, thin crust
# Pizza with: thin crust, white sauce, thick crust, thick crust
# Pizza with: thin crust, white sauce, thick crust, tomato sauce
# Pizza with: thin crust, white sauce, thick crust, white sauce
# Pizza with: thin crust, white sauce, thick crust, mozzarella
# Pizza with: thin crust, white sauce, thick crust, cheddar
# Pizza with: thin crust, white sauce, thick crust, pepperoni
# Pizza with: thin crust, white sauce, thick crust, mushrooms
# Pizza with: thin crust, white sauce, thick crust, onions
# Pizza with: thin crust, white sauce, tomato sauce, thin crust
# Pizza with: thin crust, white sauce, tomato sauce, thick crust
# Pizza with: thin crust, white sauce, tomato sauce, tomato sauce
# Pizza with: thin crust, white sauce, tomato sauce, white sauce
# Pizza with: thin crust, white sauce, tomato sauce, mozzarella
# Pizza with: thin crust, white sauce, tomato sauce, cheddar
# Pizza with: thin crust, white sauce, tomato sauce, pepperoni
# Pizza with: thin crust, white sauce, tomato sauce, mushrooms
# Pizza with: thin crust, white sauce, tomato sauce, onions
# Pizza with: thin crust, white sauce, white sauce, thin crust
# Pizza with: thin crust, white sauce, white sauce, thick crust
# Pizza with: thin crust, white sauce, white sauce, tomato sauce
# Pizza with: thin crust, white sauce, white sauce, white sauce
# Pizza with: thin crust, white sauce, white sauce, mozzarella
# Pizza with: thin crust, white sauce, white sauce, cheddar
# Pizza with: thin crust, white sauce, white sauce, pepperoni
# Pizza with: thin crust, white sauce, white sauce, mushrooms
# Pizza with: thin crust, white sauce, white sauce, onions
# Pizza with: thin crust, white sauce, mozzarella, thin crust
# Pizza with: thin crust, white sauce, mozzarella, thick crust
# Pizza with: thin crust, white sauce, mozzarella, tomato sauce
# Pizza with: thin crust, white sauce, mozzarella, white sauce
# Pizza with: thin crust, white sauce, mozzarella, mozzarella
# Pizza with: thin crust, white sauce, mozzarella, cheddar
# Pizza with: thin crust, white sauce, mozzarella, pepperoni
# Pizza with: thin crust, white sauce, mozzarella, mushrooms
# Pizza with: thin crust, white sauce, mozzarella, onions
# Pizza with: thin crust, white sauce, cheddar, thin crust
# Pizza with: thin crust, white sauce, cheddar, thick crust
# Pizza with: thin crust, white sauce, cheddar, tomato sauce
# Pizza with: thin crust, white sauce, cheddar, white sauce
# Pizza with: thin crust, white sauce, cheddar, mozzarella
# Pizza with: thin crust, white sauce, cheddar, cheddar
# Pizza with: thin crust, white sauce, cheddar, pepperoni
# Pizza with: thin crust, white sauce, cheddar, mushrooms
# Pizza with: thin crust, white sauce, cheddar, onions
# Pizza with: thin crust, white sauce, pepperoni, thin crust
# Pizza with: thin crust, white sauce, pepperoni, thick crust
# Pizza with: thin crust, white sauce, pepperoni, tomato sauce
# Pizza with: thin crust, white sauce, pepperoni, white sauce
# Pizza with: thin crust, white sauce, pepperoni, mozzarella
# Pizza with: thin crust, white sauce, pepperoni, cheddar
# Pizza with: thin crust, white sauce, pepperoni, pepperoni
# Pizza with: thin crust, white sauce, pepperoni, mushrooms
# Pizza with: thin crust, white sauce, pepperoni, onions
# Pizza with: thin crust, white sauce, mushrooms, thin crust
# Pizza with: thin crust, white sauce, mushrooms, thick crust
# Pizza with: thin crust, white sauce, mushrooms, tomato sauce
# Pizza with: thin crust, white sauce, mushrooms, white sauce
# Pizza with: thin crust, white sauce, mushrooms, mozzarella
# Pizza with: thin crust, white sauce, mushrooms, cheddar
# Pizza with: thin crust, white sauce, mushrooms, pepperoni
# Pizza with: thin crust, white sauce, mushrooms, mushrooms
# Pizza with: thin crust, white sauce, mushrooms, onions
# Pizza with: thin crust, white sauce, onions, thin crust
# Pizza with: thin crust, white sauce, onions, thick crust
# Pizza with: thin crust, white sauce, onions, tomato sauce
# Pizza with: thin crust, white sauce, onions, white sauce
# Pizza with: thin crust, white sauce, onions, mozzarella
# Pizza with: thin crust, white sauce, onions, cheddar
# Pizza with: thin crust, white sauce, onions, pepperoni
# Pizza with: thin crust, white sauce, onions, mushrooms
# Pizza with: thin crust, white sauce, onions, onions
# Pizza with: thin crust, mozzarella, thin crust, thin crust
# Pizza with: thin crust, mozzarella, thin crust, thick crust
# Pizza with: thin crust, mozzarella, thin crust, tomato sauce
# Pizza with: thin crust, mozzarella, thin crust, white sauce
# Pizza with: thin crust, mozzarella, thin crust, mozzarella
# Pizza with: thin crust, mozzarella, thin crust, cheddar
# Pizza with: thin crust, mozzarella, thin crust, pepperoni
# Pizza with: thin crust, mozzarella, thin crust, mushrooms
# Pizza with: thin crust, mozzarella, thin crust, onions
# Pizza with: thin crust, mozzarella, thick crust, thin crust
# Pizza with: thin crust, mozzarella, thick crust, thick crust
# Pizza with: thin crust, mozzarella, thick crust, tomato sauce
# Pizza with: thin crust, mozzarella, thick crust, white sauce
# Pizza with: thin crust, mozzarella, thick crust, mozzarella
# Pizza with: thin crust, mozzarella, thick crust, cheddar
# Pizza with: thin crust, mozzarella, thick crust, pepperoni
# Pizza with: thin crust, mozzarella, thick crust, mushrooms
# Pizza with: thin crust, mozzarella, thick crust, onions
# Pizza with: thin crust, mozzarella, tomato sauce, thin crust
# Pizza with: thin crust, mozzarella, tomato sauce, thick crust
# Pizza with: thin crust, mozzarella, tomato sauce, tomato sauce
# Pizza with: thin crust, mozzarella, tomato sauce, white sauce
# Pizza with: thin crust, mozzarella, tomato sauce, mozzarella
# Pizza with: thin crust, mozzarella, tomato sauce, cheddar
# Pizza with: thin crust, mozzarella, tomato sauce, pepperoni
# Pizza with: thin crust, mozzarella, tomato sauce, mushrooms
# Pizza with: thin crust, mozzarella, tomato sauce, onions
# Pizza with: thin crust, mozzarella, white sauce, thin crust
# Pizza with: thin crust, mozzarella, white sauce, thick crust
# Pizza with: thin crust, mozzarella, white sauce, tomato sauce
# Pizza with: thin crust, mozzarella, white sauce, white sauce
# Pizza with: thin crust, mozzarella, white sauce, mozzarella
# Pizza with: thin crust, mozzarella, white sauce, cheddar
# Pizza with: thin crust, mozzarella, white sauce, pepperoni
# Pizza with: thin crust, mozzarella, white sauce, mushrooms
# Pizza with: thin crust, mozzarella, white sauce, onions
# Pizza with: thin crust, mozzarella, mozzarella, thin crust
# Pizza with: thin crust, mozzarella, mozzarella, thick crust
# Pizza with: thin crust, mozzarella, mozzarella, tomato sauce
# Pizza with: thin crust, mozzarella, mozzarella, white sauce
# Pizza with: thin crust, mozzarella, mozzarella, mozzarella
# Pizza with: thin crust, mozzarella, mozzarella, cheddar
# Pizza with: thin crust, mozzarella, mozzarella, pepperoni
# Pizza with: thin crust, mozzarella, mozzarella, mushrooms
# Pizza with: thin crust, mozzarella, mozzarella, onions
# Pizza with: thin crust, mozzarella, cheddar, thin crust
# Pizza with: thin crust, mozzarella, cheddar, thick crust
# Pizza with: thin crust, mozzarella, cheddar, tomato sauce
# Pizza with: thin crust, mozzarella, cheddar, white sauce
# Pizza with: thin crust, mozzarella, cheddar, mozzarella
# Pizza with: thin crust, mozzarella, cheddar, cheddar
# Pizza with: thin crust, mozzarella, cheddar, pepperoni
# Pizza with: thin crust, mozzarella, cheddar, mushrooms
# Pizza with: thin crust, mozzarella, cheddar, onions
# Pizza with: thin crust, mozzarella, pepperoni, thin crust
# Pizza with: thin crust, mozzarella, pepperoni, thick crust
# Pizza with: thin crust, mozzarella, pepperoni, tomato sauce
# Pizza with: thin crust, mozzarella, pepperoni, white sauce
# Pizza with: thin crust, mozzarella, pepperoni, mozzarella
# Pizza with: thin crust, mozzarella, pepperoni, cheddar
# Pizza with: thin crust, mozzarella, pepperoni, pepperoni
# Pizza with: thin crust, mozzarella, pepperoni, mushrooms
# Pizza with: thin crust, mozzarella, pepperoni, onions
# Pizza with: thin crust, mozzarella, mushrooms, thin crust
# Pizza with: thin crust, mozzarella, mushrooms, thick crust
# Pizza with: thin crust, mozzarella, mushrooms, tomato sauce
# Pizza with: thin crust, mozzarella, mushrooms, white sauce
# Pizza with: thin crust, mozzarella, mushrooms, mozzarella
# Pizza with: thin crust, mozzarella, mushrooms, cheddar
# Pizza with: thin crust, mozzarella, mushrooms, pepperoni
# Pizza with: thin crust, mozzarella, mushrooms, mushrooms
# Pizza with: thin crust, mozzarella, mushrooms, onions
# Pizza with: thin crust, mozzarella, onions, thin crust
# Pizza with: thin crust, mozzarella, onions, thick crust
# Pizza with: thin crust, mozzarella, onions, tomato sauce
# Pizza with: thin crust, mozzarella, onions, white sauce
# Pizza with: thin crust, mozzarella, onions, mozzarella
# Pizza with: thin crust, mozzarella, onions, cheddar
# Pizza with: thin crust, mozzarella, onions, pepperoni
# Pizza with: thin crust, mozzarella, onions, mushrooms
# Pizza with: thin crust, mozzarella, onions, onions
# Pizza with: thin crust, cheddar, thin crust, thin crust
# Pizza with: thin crust, cheddar, thin crust, thick crust
# Pizza with: thin crust, cheddar, thin crust, tomato sauce
# Pizza with: thin crust, cheddar, thin crust, white sauce
# Pizza with: thin crust, cheddar, thin crust, mozzarella
# Pizza with: thin crust, cheddar, thin crust, cheddar
# Pizza with: thin crust, cheddar, thin crust, pepperoni
# Pizza with: thin crust, cheddar, thin crust, mushrooms
# Pizza with: thin crust, cheddar, thin crust, onions
# Pizza with: thin crust, cheddar, thick crust, thin crust
# Pizza with: thin crust, cheddar, thick crust, thick crust
# Pizza with: thin crust, cheddar, thick crust, tomato sauce
# Pizza with: thin crust, cheddar, thick crust, white sauce
# Pizza with: thin crust, cheddar, thick crust, mozzarella
# Pizza with: thin crust, cheddar, thick crust, cheddar
# Pizza with: thin crust, cheddar, thick crust, pepperoni
# Pizza with: thin crust, cheddar, thick crust, mushrooms
# Pizza with: thin crust, cheddar, thick crust, onions
# Pizza with: thin crust, cheddar, tomato sauce, thin crust
# Pizza with: thin crust, cheddar, tomato sauce, thick crust
# Pizza with: thin crust, cheddar, tomato sauce, tomato sauce
# Pizza with: thin crust, cheddar, tomato sauce, white sauce
# Pizza with: thin crust, cheddar, tomato sauce, mozzarella
# Pizza with: thin crust, cheddar, tomato sauce, cheddar
# Pizza with: thin crust, cheddar, tomato sauce, pepperoni
# Pizza with: thin crust, cheddar, tomato sauce, mushrooms
# Pizza with: thin crust, cheddar, tomato sauce, onions
# Pizza with: thin crust, cheddar, white sauce, thin crust
# Pizza with: thin crust, cheddar, white sauce, thick crust
# Pizza with: thin crust, cheddar, white sauce, tomato sauce
# Pizza with: thin crust, cheddar, white sauce, white sauce
# Pizza with: thin crust, cheddar, white sauce, mozzarella
# Pizza with: thin crust, cheddar, white sauce, cheddar
# Pizza with: thin crust, cheddar, white sauce, pepperoni
# Pizza with: thin crust, cheddar, white sauce, mushrooms
# Pizza with: thin crust, cheddar, white sauce, onions
# Pizza with: thin crust, cheddar, mozzarella, thin crust
# Pizza with: thin crust, cheddar, mozzarella, thick crust
# Pizza with: thin crust, cheddar, mozzarella, tomato sauce
# Pizza with: thin crust, cheddar, mozzarella, white sauce
# Pizza with: thin crust, cheddar, mozzarella, mozzarella
# Pizza with: thin crust, cheddar, mozzarella, cheddar
# Pizza with: thin crust, cheddar, mozzarella, pepperoni
# Pizza with: thin crust, cheddar, mozzarella, mushrooms
# Pizza with: thin crust, cheddar, mozzarella, onions
# Pizza with: thin crust, cheddar, cheddar, thin crust
# Pizza with: thin crust, cheddar, cheddar, thick crust
# Pizza with: thin crust, cheddar, cheddar, tomato sauce
# Pizza with: thin crust, cheddar, cheddar, white sauce
# Pizza with: thin crust, cheddar, cheddar, mozzarella
# Pizza with: thin crust, cheddar, cheddar, cheddar
# Pizza with: thin crust, cheddar, cheddar, pepperoni
# Pizza with: thin crust, cheddar, cheddar, mushrooms
# Pizza with: thin crust, cheddar, cheddar, onions
# Pizza with: thin crust, cheddar, pepperoni, thin crust
# Pizza with: thin crust, cheddar, pepperoni, thick crust
# Pizza with: thin crust, cheddar, pepperoni, tomato sauce
# Pizza with: thin crust, cheddar, pepperoni, white sauce
# Pizza with: thin crust, cheddar, pepperoni, mozzarella
# Pizza with: thin crust, cheddar, pepperoni, cheddar
# Pizza with: thin crust, cheddar, pepperoni, pepperoni
# Pizza with: thin crust, cheddar, pepperoni, mushrooms
# Pizza with: thin crust, cheddar, pepperoni, onions
# Pizza with: thin crust, cheddar, mushrooms, thin crust
# Pizza with: thin crust, cheddar, mushrooms, thick crust
# Pizza with: thin crust, cheddar, mushrooms, tomato sauce
# Pizza with: thin crust, cheddar, mushrooms, white sauce
# Pizza with: thin crust, cheddar, mushrooms, mozzarella
# Pizza with: thin crust, cheddar, mushrooms, cheddar
# Pizza with: thin crust, cheddar, mushrooms, pepperoni
# Pizza with: thin crust, cheddar, mushrooms, mushrooms
# Pizza with: thin crust, cheddar, mushrooms, onions
# Pizza with: thin crust, cheddar, onions, thin crust
# Pizza with: thin crust, cheddar, onions, thick crust
# Pizza with: thin crust, cheddar, onions, tomato sauce
# Pizza with: thin crust, cheddar, onions, white sauce
# Pizza with: thin crust, cheddar, onions, mozzarella
# Pizza with: thin crust, cheddar, onions, cheddar
# Pizza with: thin crust, cheddar, onions, pepperoni
# Pizza with: thin crust, cheddar, onions, mushrooms
# Pizza with: thin crust, cheddar, onions, onions
# Pizza with: thin crust, pepperoni, thin crust, thin crust
# Pizza with: thin crust, pepperoni, thin crust, thick crust
# Pizza with: thin crust, pepperoni, thin crust, tomato sauce
# Pizza with: thin crust, pepperoni, thin crust, white sauce
# Pizza with: thin crust, pepperoni, thin crust, mozzarella
# Pizza with: thin crust, pepperoni, thin crust, cheddar
# Pizza with: thin crust, pepperoni, thin crust, pepperoni
# Pizza with: thin crust, pepperoni, thin crust, mushrooms
# Pizza with: thin crust, pepperoni, thin crust, onions
# Pizza with: thin crust, pepperoni, thick crust, thin crust
# Pizza with: thin crust, pepperoni, thick crust, thick crust
# Pizza with: thin crust, pepperoni, thick crust, tomato sauce
# Pizza with: thin crust, pepperoni, thick crust, white sauce
# Pizza with: thin crust, pepperoni, thick crust, mozzarella
# Pizza with: thin crust, pepperoni, thick crust, cheddar
# Pizza with: thin crust, pepperoni, thick crust, pepperoni
# Pizza with: thin crust, pepperoni, thick crust, mushrooms
# Pizza with: thin crust, pepperoni, thick crust, onions
# Pizza with: thin crust, pepperoni, tomato sauce, thin crust
# Pizza with: thin crust, pepperoni, tomato sauce, thick crust
# Pizza with: thin crust, pepperoni, tomato sauce, tomato sauce
# Pizza with: thin crust, pepperoni, tomato sauce, white sauce
# Pizza with: thin crust, pepperoni, tomato sauce, mozzarella
# Pizza with: thin crust, pepperoni, tomato sauce, cheddar
# Pizza with: thin crust, pepperoni, tomato sauce, pepperoni
# Pizza with: thin crust, pepperoni, tomato sauce, mushrooms
# Pizza with: thin crust, pepperoni, tomato sauce, onions
# Pizza with: thin crust, pepperoni, white sauce, thin crust
# Pizza with: thin crust, pepperoni, white sauce, thick crust
# Pizza with: thin crust, pepperoni, white sauce, tomato sauce
# Pizza with: thin crust, pepperoni, white sauce, white sauce
# Pizza with: thin crust, pepperoni, white sauce, mozzarella
# Pizza with: thin crust, pepperoni, white sauce, cheddar
# Pizza with: thin crust, pepperoni, white sauce, pepperoni
# Pizza with: thin crust, pepperoni, white sauce, mushrooms
# Pizza with: thin crust, pepperoni, white sauce, onions
# Pizza with: thin crust, pepperoni, mozzarella, thin crust
# Pizza with: thin crust, pepperoni, mozzarella, thick crust
# Pizza with: thin crust, pepperoni, mozzarella, tomato sauce
# Pizza with: thin crust, pepperoni, mozzarella, white sauce
# Pizza with: thin crust, pepperoni, mozzarella, mozzarella
# Pizza with: thin crust, pepperoni, mozzarella, cheddar
# Pizza with: thin crust, pepperoni, mozzarella, pepperoni
# Pizza with: thin crust, pepperoni, mozzarella, mushrooms
# Pizza with: thin crust, pepperoni, mozzarella, onions
# Pizza with: thin crust, pepperoni, cheddar, thin crust
# Pizza with: thin crust, pepperoni, cheddar, thick crust
# Pizza with: thin crust, pepperoni, cheddar, tomato sauce
# Pizza with: thin crust, pepperoni, cheddar, white sauce
# Pizza with: thin crust, pepperoni, cheddar, mozzarella
# Pizza with: thin crust, pepperoni, cheddar, cheddar
# Pizza with: thin crust, pepperoni, cheddar, pepperoni
# Pizza with: thin crust, pepperoni, cheddar, mushrooms
# Pizza with: thin crust, pepperoni, cheddar, onions
# Pizza with: thin crust, pepperoni, pepperoni, thin crust
# Pizza with: thin crust, pepperoni, pepperoni, thick crust
# Pizza with: thin crust, pepperoni, pepperoni, tomato sauce
# Pizza with: thin crust, pepperoni, pepperoni, white sauce
# Pizza with: thin crust, pepperoni, pepperoni, mozzarella
# Pizza with: thin crust, pepperoni, pepperoni, cheddar
# Pizza with: thin crust, pepperoni, pepperoni, pepperoni
# Pizza with: thin crust, pepperoni, pepperoni, mushrooms
# Pizza with: thin crust, pepperoni, pepperoni, onions
# Pizza with: thin crust, pepperoni, mushrooms, thin crust
# Pizza with: thin crust, pepperoni, mushrooms, thick crust
# Pizza with: thin crust, pepperoni, mushrooms, tomato sauce
# Pizza with: thin crust, pepperoni, mushrooms, white sauce
# Pizza with: thin crust, pepperoni, mushrooms, mozzarella
# Pizza with: thin crust, pepperoni, mushrooms, cheddar
# Pizza with: thin crust, pepperoni, mushrooms, pepperoni
# Pizza with: thin crust, pepperoni, mushrooms, mushrooms
# Pizza with: thin crust, pepperoni, mushrooms, onions
# Pizza with: thin crust, pepperoni, onions, thin crust
# Pizza with: thin crust, pepperoni, onions, thick crust
# Pizza with: thin crust, pepperoni, onions, tomato sauce
# Pizza with: thin crust, pepperoni, onions, white sauce
# Pizza with: thin crust, pepperoni, onions, mozzarella
# Pizza with: thin crust, pepperoni, onions, cheddar
# Pizza with: thin crust, pepperoni, onions, pepperoni
# Pizza with: thin crust, pepperoni, onions, mushrooms
# Pizza with: thin crust, pepperoni, onions, onions
# Pizza with: thin crust, mushrooms, thin crust, thin crust
# Pizza with: thin crust, mushrooms, thin crust, thick crust
# Pizza with: thin crust, mushrooms, thin crust, tomato sauce
# Pizza with: thin crust, mushrooms, thin crust, white sauce
# Pizza with: thin crust, mushrooms, thin crust, mozzarella
# Pizza with: thin crust, mushrooms, thin crust, cheddar
# Pizza with: thin crust, mushrooms, thin crust, pepperoni
# Pizza with: thin crust, mushrooms, thin crust, mushrooms
# Pizza with: thin crust, mushrooms, thin crust, onions
# Pizza with: thin crust, mushrooms, thick crust, thin crust
# Pizza with: thin crust, mushrooms, thick crust, thick crust
# Pizza with: thin crust, mushrooms, thick crust, tomato sauce
# Pizza with: thin crust, mushrooms, thick crust, white sauce
# Pizza with: thin crust, mushrooms, thick crust, mozzarella
# Pizza with: thin crust, mushrooms, thick crust, cheddar
# Pizza with: thin crust, mushrooms, thick crust, pepperoni
# Pizza with: thin crust, mushrooms, thick crust, mushrooms
# Pizza with: thin crust, mushrooms, thick crust, onions
# Pizza with: thin crust, mushrooms, tomato sauce, thin crust
# Pizza with: thin crust, mushrooms, tomato sauce, thick crust
# Pizza with: thin crust, mushrooms, tomato sauce, tomato sauce
# Pizza with: thin crust, mushrooms, tomato sauce, white sauce
# Pizza with: thin crust, mushrooms, tomato sauce, mozzarella
# Pizza with: thin crust, mushrooms, tomato sauce, cheddar
# Pizza with: thin crust, mushrooms, tomato sauce, pepperoni
# Pizza with: thin crust, mushrooms, tomato sauce, mushrooms
# Pizza with: thin crust, mushrooms, tomato sauce, onions
# Pizza with: thin crust, mushrooms, white sauce, thin crust
# Pizza with: thin crust, mushrooms, white sauce, thick crust
# Pizza with: thin crust, mushrooms, white sauce, tomato sauce
# Pizza with: thin crust, mushrooms, white sauce, white sauce
# Pizza with: thin crust, mushrooms, white sauce, mozzarella
# Pizza with: thin crust, mushrooms, white sauce, cheddar
# Pizza with: thin crust, mushrooms, white sauce, pepperoni
# Pizza with: thin crust, mushrooms, white sauce, mushrooms
# Pizza with: thin crust, mushrooms, white sauce, onions
# Pizza with: thin crust, mushrooms, mozzarella, thin crust
# Pizza with: thin crust, mushrooms, mozzarella, thick crust
# Pizza with: thin crust, mushrooms, mozzarella, tomato sauce
# Pizza with: thin crust, mushrooms, mozzarella, white sauce
# Pizza with: thin crust, mushrooms, mozzarella, mozzarella
# Pizza with: thin crust, mushrooms, mozzarella, cheddar
# Pizza with: thin crust, mushrooms, mozzarella, pepperoni
# Pizza with: thin crust, mushrooms, mozzarella, mushrooms
# Pizza with: thin crust, mushrooms, mozzarella, onions
# Pizza with: thin crust, mushrooms, cheddar, thin crust
# Pizza with: thin crust, mushrooms, cheddar, thick crust
# Pizza with: thin crust, mushrooms, cheddar, tomato sauce
# Pizza with: thin crust, mushrooms, cheddar, white sauce
# Pizza with: thin crust, mushrooms, cheddar, mozzarella
# Pizza with: thin crust, mushrooms, cheddar, cheddar
# Pizza with: thin crust, mushrooms, cheddar, pepperoni
# Pizza with: thin crust, mushrooms, cheddar, mushrooms
# Pizza with: thin crust, mushrooms, cheddar, onions
# Pizza with: thin crust, mushrooms, pepperoni, thin crust
# Pizza with: thin crust, mushrooms, pepperoni, thick crust
# Pizza with: thin crust, mushrooms, pepperoni, tomato sauce
# Pizza with: thin crust, mushrooms, pepperoni, white sauce
# Pizza with: thin crust, mushrooms, pepperoni, mozzarella
# Pizza with: thin crust, mushrooms, pepperoni, cheddar
# Pizza with: thin crust, mushrooms, pepperoni, pepperoni
# Pizza with: thin crust, mushrooms, pepperoni, mushrooms
# Pizza with: thin crust, mushrooms, pepperoni, onions
# Pizza with: thin crust, mushrooms, mushrooms, thin crust
# Pizza with: thin crust, mushrooms, mushrooms, thick crust
# Pizza with: thin crust, mushrooms, mushrooms, tomato sauce
# Pizza with: thin crust, mushrooms, mushrooms, white sauce
# Pizza with: thin crust, mushrooms, mushrooms, mozzarella
# Pizza with: thin crust, mushrooms, mushrooms, cheddar
# Pizza with: thin crust, mushrooms, mushrooms, pepperoni
# Pizza with: thin crust, mushrooms, mushrooms, mushrooms
# Pizza with: thin crust, mushrooms, mushrooms, onions
# Pizza with: thin crust, mushrooms, onions, thin crust
# Pizza with: thin crust, mushrooms, onions, thick crust
# Pizza with: thin crust, mushrooms, onions, tomato sauce
# Pizza with: thin crust, mushrooms, onions, white sauce
# Pizza with: thin crust, mushrooms, onions, mozzarella
# Pizza with: thin crust, mushrooms, onions, cheddar
# Pizza with: thin crust, mushrooms, onions, pepperoni
# Pizza with: thin crust, mushrooms, onions, mushrooms
# Pizza with: thin crust, mushrooms, onions, onions
# Pizza with: thin crust, onions, thin crust, thin crust
# Pizza with: thin crust, onions, thin crust, thick crust
# Pizza with: thin crust, onions, thin crust, tomato sauce
# Pizza with: thin crust, onions, thin crust, white sauce
# Pizza with: thin crust, onions, thin crust, mozzarella
# Pizza with: thin crust, onions, thin crust, cheddar
# Pizza with: thin crust, onions, thin crust, pepperoni
# Pizza with: thin crust, onions, thin crust, mushrooms
# Pizza with: thin crust, onions, thin crust, onions
# Pizza with: thin crust, onions, thick crust, thin crust
# Pizza with: thin crust, onions, thick crust, thick crust
# Pizza with: thin crust, onions, thick crust, tomato sauce
# Pizza with: thin crust, onions, thick crust, white sauce
# Pizza with: thin crust, onions, thick crust, mozzarella
# Pizza with: thin crust, onions, thick crust, cheddar
# Pizza with: thin crust, onions, thick crust, pepperoni
# Pizza with: thin crust, onions, thick crust, mushrooms
# Pizza with: thin crust, onions, thick crust, onions
# Pizza with: thin crust, onions, tomato sauce, thin crust
# Pizza with: thin crust, onions, tomato sauce, thick crust
# Pizza with: thin crust, onions, tomato sauce, tomato sauce
# Pizza with: thin crust, onions, tomato sauce, white sauce
# Pizza with: thin crust, onions, tomato sauce, mozzarella
# Pizza with: thin crust, onions, tomato sauce, cheddar
# Pizza with: thin crust, onions, tomato sauce, pepperoni
# Pizza with: thin crust, onions, tomato sauce, mushrooms
# Pizza with: thin crust, onions, tomato sauce, onions
# Pizza with: thin crust, onions, white sauce, thin crust
# Pizza with: thin crust, onions, white sauce, thick crust
# Pizza with: thin crust, onions, white sauce, tomato sauce
# Pizza with: thin crust, onions, white sauce, white sauce
# Pizza with: thin crust, onions, white sauce, mozzarella
# Pizza with: thin crust, onions, white sauce, cheddar
# Pizza with: thin crust, onions, white sauce, pepperoni
# Pizza with: thin crust, onions, white sauce, mushrooms
# Pizza with: thin crust, onions, white sauce, onions
# Pizza with: thin crust, onions, mozzarella, thin crust
# Pizza with: thin crust, onions, mozzarella, thick crust
# Pizza with: thin crust, onions, mozzarella, tomato sauce
# Pizza with: thin crust, onions, mozzarella, white sauce
# Pizza with: thin crust, onions, mozzarella, mozzarella
# Pizza with: thin crust, onions, mozzarella, cheddar
# Pizza with: thin crust, onions, mozzarella, pepperoni
# Pizza with: thin crust, onions, mozzarella, mushrooms
# Pizza with: thin crust, onions, mozzarella, onions
# Pizza with: thin crust, onions, cheddar, thin crust
# Pizza with: thin crust, onions, cheddar, thick crust
# Pizza with: thin crust, onions, cheddar, tomato sauce
# Pizza with: thin crust, onions, cheddar, white sauce
# Pizza with: thin crust, onions, cheddar, mozzarella
# Pizza with: thin crust, onions, cheddar, cheddar
# Pizza with: thin crust, onions, cheddar, pepperoni
# Pizza with: thin crust, onions, cheddar, mushrooms
# Pizza with: thin crust, onions, cheddar, onions
# Pizza with: thin crust, onions, pepperoni, thin crust
# Pizza with: thin crust, onions, pepperoni, thick crust
# Pizza with: thin crust, onions, pepperoni, tomato sauce
# Pizza with: thin crust, onions, pepperoni, white sauce
# Pizza with: thin crust, onions, pepperoni, mozzarella
# Pizza with: thin crust, onions, pepperoni, cheddar
# Pizza with: thin crust, onions, pepperoni, pepperoni
# Pizza with: thin crust, onions, pepperoni, mushrooms
# Pizza with: thin crust, onions, pepperoni, onions
# Pizza with: thin crust, onions, mushrooms, thin crust
# Pizza with: thin crust, onions, mushrooms, thick crust
# Pizza with: thin crust, onions, mushrooms, tomato sauce
# Pizza with: thin crust, onions, mushrooms, white sauce
# Pizza with: thin crust, onions, mushrooms, mozzarella
# Pizza with: thin crust, onions, mushrooms, cheddar
# Pizza with: thin crust, onions, mushrooms, pepperoni
# Pizza with: thin crust, onions, mushrooms, mushrooms
# Pizza with: thin crust, onions, mushrooms, onions
# Pizza with: thin crust, onions, onions, thin crust
# Pizza with: thin crust, onions, onions, thick crust
# Pizza with: thin crust, onions, onions, tomato sauce
# Pizza with: thin crust, onions, onions, white sauce
# Pizza with: thin crust, onions, onions, mozzarella
# Pizza with: thin crust, onions, onions, cheddar
# Pizza with: thin crust, onions, onions, pepperoni
# Pizza with: thin crust, onions, onions, mushrooms
# Pizza with: thin crust, onions, onions, onions
# Pizza with: thick crust, thin crust, thin crust, thin crust
# Pizza with: thick crust, thin crust, thin crust, thick crust
# Pizza with: thick crust, thin crust, thin crust, tomato sauce
# Pizza with: thick crust, thin crust, thin crust, white sauce
# Pizza with: thick crust, thin crust, thin crust, mozzarella
# Pizza with: thick crust, thin crust, thin crust, cheddar
# Pizza with: thick crust, thin crust, thin crust, pepperoni
# Pizza with: thick crust, thin crust, thin crust, mushrooms
# Pizza with: thick crust, thin crust, thin crust, onions
# Pizza with: thick crust, thin crust, thick crust, thin crust
# Pizza with: thick crust, thin crust, thick crust, thick crust
# Pizza with: thick crust, thin crust, thick crust, tomato sauce
# Pizza with: thick crust, thin crust, thick crust, white sauce
# Pizza with: thick crust, thin crust, thick crust, mozzarella
# Pizza with: thick crust, thin crust, thick crust, cheddar
# Pizza with: thick crust, thin crust, thick crust, pepperoni
# Pizza with: thick crust, thin crust, thick crust, mushrooms
# Pizza with: thick crust, thin crust, thick crust, onions
# Pizza with: thick crust, thin crust, tomato sauce, thin crust
# Pizza with: thick crust, thin crust, tomato sauce, thick crust
# Pizza with: thick crust, thin crust, tomato sauce, tomato sauce
# Pizza with: thick crust, thin crust, tomato sauce, white sauce
# Pizza with: thick crust, thin crust, tomato sauce, mozzarella
# Pizza with: thick crust, thin crust, tomato sauce, cheddar
# Pizza with: thick crust, thin crust, tomato sauce, pepperoni
# Pizza with: thick crust, thin crust, tomato sauce, mushrooms
# Pizza with: thick crust, thin crust, tomato sauce, onions
# Pizza with: thick crust, thin crust, white sauce, thin crust
# Pizza with: thick crust, thin crust, white sauce, thick crust
# Pizza with: thick crust, thin crust, white sauce, tomato sauce
# Pizza with: thick crust, thin crust, white sauce, white sauce
# Pizza with: thick crust, thin crust, white sauce, mozzarella
# Pizza with: thick crust, thin crust, white sauce, cheddar
# Pizza with: thick crust, thin crust, white sauce, pepperoni
# Pizza with: thick crust, thin crust, white sauce, mushrooms
# Pizza with: thick crust, thin crust, white sauce, onions
# Pizza with: thick crust, thin crust, mozzarella, thin crust
# Pizza with: thick crust, thin crust, mozzarella, thick crust
# Pizza with: thick crust, thin crust, mozzarella, tomato sauce
# Pizza with: thick crust, thin crust, mozzarella, white sauce
# Pizza with: thick crust, thin crust, mozzarella, mozzarella
# Pizza with: thick crust, thin crust, mozzarella, cheddar
# Pizza with: thick crust, thin crust, mozzarella, pepperoni
# Pizza with: thick crust, thin crust, mozzarella, mushrooms
# Pizza with: thick crust, thin crust, mozzarella, onions
# Pizza with: thick crust, thin crust, cheddar, thin crust
# Pizza with: thick crust, thin crust, cheddar, thick crust
# Pizza with: thick crust, thin crust, cheddar, tomato sauce
# Pizza with: thick crust, thin crust, cheddar, white sauce
# Pizza with: thick crust, thin crust, cheddar, mozzarella
# Pizza with: thick crust, thin crust, cheddar, cheddar
# Pizza with: thick crust, thin crust, cheddar, pepperoni
# Pizza with: thick crust, thin crust, cheddar, mushrooms
# Pizza with: thick crust, thin crust, cheddar, onions
# Pizza with: thick crust, thin crust, pepperoni, thin crust
# Pizza with: thick crust, thin crust, pepperoni, thick crust
# Pizza with: thick crust, thin crust, pepperoni, tomato sauce
# Pizza with: thick crust, thin crust, pepperoni, white sauce
# Pizza with: thick crust, thin crust, pepperoni, mozzarella
# Pizza with: thick crust, thin crust, pepperoni, cheddar
# Pizza with: thick crust, thin crust, pepperoni, pepperoni
# Pizza with: thick crust, thin crust, pepperoni, mushrooms
# Pizza with: thick crust, thin crust, pepperoni, onions
# Pizza with: thick crust, thin crust, mushrooms, thin crust
# Pizza with: thick crust, thin crust, mushrooms, thick crust
# Pizza with: thick crust, thin crust, mushrooms, tomato sauce
# Pizza with: thick crust, thin crust, mushrooms, white sauce
# Pizza with: thick crust, thin crust, mushrooms, mozzarella
# Pizza with: thick crust, thin crust, mushrooms, cheddar
# Pizza with: thick crust, thin crust, mushrooms, pepperoni
# Pizza with: thick crust, thin crust, mushrooms, mushrooms
# Pizza with: thick crust, thin crust, mushrooms, onions
# Pizza with: thick crust, thin crust, onions, thin crust
# Pizza with: thick crust, thin crust, onions, thick crust
# Pizza with: thick crust, thin crust, onions, tomato sauce
# Pizza with: thick crust, thin crust, onions, white sauce
# Pizza with: thick crust, thin crust, onions, mozzarella
# Pizza with: thick crust, thin crust, onions, cheddar
# Pizza with: thick crust, thin crust, onions, pepperoni
# Pizza with: thick crust, thin crust, onions, mushrooms
# Pizza with: thick crust, thin crust, onions, onions
# Pizza with: thick crust, thick crust, thin crust, thin crust
# Pizza with: thick crust, thick crust, thin crust, thick crust
# Pizza with: thick crust, thick crust, thin crust, tomato sauce
# Pizza with: thick crust, thick crust, thin crust, white sauce
# Pizza with: thick crust, thick crust, thin crust, mozzarella
# Pizza with: thick crust, thick crust, thin crust, cheddar
# Pizza with: thick crust, thick crust, thin crust, pepperoni
# Pizza with: thick crust, thick crust, thin crust, mushrooms
# Pizza with: thick crust, thick crust, thin crust, onions
# Pizza with: thick crust, thick crust, thick crust, thin crust
# Pizza with: thick crust, thick crust, thick crust, thick crust
# Pizza with: thick crust, thick crust, thick crust, tomato sauce
# Pizza with: thick crust, thick crust, thick crust, white sauce
# Pizza with: thick crust, thick crust, thick crust, mozzarella
# Pizza with: thick crust, thick crust, thick crust, cheddar
# Pizza with: thick crust, thick crust, thick crust, pepperoni
# Pizza with: thick crust, thick crust, thick crust, mushrooms
# Pizza with: thick crust, thick crust, thick crust, onions
# Pizza with: thick crust, thick crust, tomato sauce, thin crust
# Pizza with: thick crust, thick crust, tomato sauce, thick crust
# Pizza with: thick crust, thick crust, tomato sauce, tomato sauce
# Pizza with: thick crust, thick crust, tomato sauce, white sauce
# Pizza with: thick crust, thick crust, tomato sauce, mozzarella
# ...
# Pizza with: onions, cheddar, thick crust, pepperoni
# Pizza with: onions, cheddar, thick crust, mushrooms
# Pizza with: onions, cheddar, thick crust, onions
# Pizza with: onions, cheddar, tomato sauce, thin crust
# Pizza with: onions, cheddar, tomato sauce, thick crust
# Pizza with: onions, cheddar, tomato sauce, tomato sauce
# Pizza with: onions, cheddar, tomato sauce, white sauce
# Pizza with: onions, cheddar, tomato sauce, mozzarella
# Pizza with: onions, cheddar, tomato sauce, cheddar
# Pizza with: onions, cheddar, tomato sauce, pepperoni
# Pizza with: onions, cheddar, tomato sauce, mushrooms
# Pizza with: onions, cheddar, tomato sauce, onions
# Pizza with: onions, cheddar, white sauce, thin crust
# Pizza with: onions, cheddar, white sauce, thick crust
# Pizza with: onions, cheddar, white sauce, tomato sauce
# Pizza with: onions, cheddar, white sauce, white sauce
# Pizza with: onions, cheddar, white sauce, mozzarella
# Pizza with: onions, cheddar, white sauce, cheddar
# Pizza with: onions, cheddar, white sauce, pepperoni
# Pizza with: onions, cheddar, white sauce, mushrooms
# Pizza with: onions, cheddar, white sauce, onions
# Pizza with: onions, cheddar, mozzarella, thin crust
# Pizza with: onions, cheddar, mozzarella, thick crust
# Pizza with: onions, cheddar, mozzarella, tomato sauce
# Pizza with: onions, cheddar, mozzarella, white sauce
# Pizza with: onions, cheddar, mozzarella, mozzarella
# Pizza with: onions, cheddar, mozzarella, cheddar
# Pizza with: onions, cheddar, mozzarella, pepperoni
# Pizza with: onions, cheddar, mozzarella, mushrooms
# Pizza with: onions, cheddar, mozzarella, onions
# Pizza with: onions, cheddar, cheddar, thin crust
# Pizza with: onions, cheddar, cheddar, thick crust
# Pizza with: onions, cheddar, cheddar, tomato sauce
# Pizza with: onions, cheddar, cheddar, white sauce
# Pizza with: onions, cheddar, cheddar, mozzarella
# Pizza with: onions, cheddar, cheddar, cheddar
# Pizza with: onions, cheddar, cheddar, pepperoni
# Pizza with: onions, cheddar, cheddar, mushrooms
# Pizza with: onions, cheddar, cheddar, onions
# Pizza with: onions, cheddar, pepperoni, thin crust
# Pizza with: onions, cheddar, pepperoni, thick crust
# Pizza with: onions, cheddar, pepperoni, tomato sauce
# Pizza with: onions, cheddar, pepperoni, white sauce
# Pizza with: onions, cheddar, pepperoni, mozzarella
# Pizza with: onions, cheddar, pepperoni, cheddar
# Pizza with: onions, cheddar, pepperoni, pepperoni
# Pizza with: onions, cheddar, pepperoni, mushrooms
# Pizza with: onions, cheddar, pepperoni, onions
# Pizza with: onions, cheddar, mushrooms, thin crust
# Pizza with: onions, cheddar, mushrooms, thick crust
# Pizza with: onions, cheddar, mushrooms, tomato sauce
# Pizza with: onions, cheddar, mushrooms, white sauce
# Pizza with: onions, cheddar, mushrooms, mozzarella
# Pizza with: onions, cheddar, mushrooms, cheddar
# Pizza with: onions, cheddar, mushrooms, pepperoni
# Pizza with: onions, cheddar, mushrooms, mushrooms
# Pizza with: onions, cheddar, mushrooms, onions
# Pizza with: onions, cheddar, onions, thin crust
# Pizza with: onions, cheddar, onions, thick crust
# Pizza with: onions, cheddar, onions, tomato sauce
# Pizza with: onions, cheddar, onions, white sauce
# Pizza with: onions, cheddar, onions, mozzarella
# Pizza with: onions, cheddar, onions, cheddar
# Pizza with: onions, cheddar, onions, pepperoni
# Pizza with: onions, cheddar, onions, mushrooms
# Pizza with: onions, cheddar, onions, onions
# Pizza with: onions, pepperoni, thin crust, thin crust
# Pizza with: onions, pepperoni, thin crust, thick crust
# Pizza with: onions, pepperoni, thin crust, tomato sauce
# Pizza with: onions, pepperoni, thin crust, white sauce
# Pizza with: onions, pepperoni, thin crust, mozzarella
# Pizza with: onions, pepperoni, thin crust, cheddar
# Pizza with: onions, pepperoni, thin crust, pepperoni
# Pizza with: onions, pepperoni, thin crust, mushrooms
# Pizza with: onions, pepperoni, thin crust, onions
# Pizza with: onions, pepperoni, thick crust, thin crust
# Pizza with: onions, pepperoni, thick crust, thick crust
# Pizza with: onions, pepperoni, thick crust, tomato sauce
# Pizza with: onions, pepperoni, thick crust, white sauce
# Pizza with: onions, pepperoni, thick crust, mozzarella
# Pizza with: onions, pepperoni, thick crust, cheddar
# Pizza with: onions, pepperoni, thick crust, pepperoni
# Pizza with: onions, pepperoni, thick crust, mushrooms
# Pizza with: onions, pepperoni, thick crust, onions
# Pizza with: onions, pepperoni, tomato sauce, thin crust
# Pizza with: onions, pepperoni, tomato sauce, thick crust
# Pizza with: onions, pepperoni, tomato sauce, tomato sauce
# Pizza with: onions, pepperoni, tomato sauce, white sauce
# Pizza with: onions, pepperoni, tomato sauce, mozzarella
# Pizza with: onions, pepperoni, tomato sauce, cheddar
# Pizza with: onions, pepperoni, tomato sauce, pepperoni
# Pizza with: onions, pepperoni, tomato sauce, mushrooms
# Pizza with: onions, pepperoni, tomato sauce, onions
# Pizza with: onions, pepperoni, white sauce, thin crust
# Pizza with: onions, pepperoni, white sauce, thick crust
# Pizza with: onions, pepperoni, white sauce, tomato sauce
# Pizza with: onions, pepperoni, white sauce, white sauce
# Pizza with: onions, pepperoni, white sauce, mozzarella
# Pizza with: onions, pepperoni, white sauce, cheddar
# Pizza with: onions, pepperoni, white sauce, pepperoni
# Pizza with: onions, pepperoni, white sauce, mushrooms
# Pizza with: onions, pepperoni, white sauce, onions
# Pizza with: onions, pepperoni, mozzarella, thin crust
# Pizza with: onions, pepperoni, mozzarella, thick crust
# Pizza with: onions, pepperoni, mozzarella, tomato sauce
# Pizza with: onions, pepperoni, mozzarella, white sauce
# Pizza with: onions, pepperoni, mozzarella, mozzarella
# Pizza with: onions, pepperoni, mozzarella, cheddar
# Pizza with: onions, pepperoni, mozzarella, pepperoni
# Pizza with: onions, pepperoni, mozzarella, mushrooms
# Pizza with: onions, pepperoni, mozzarella, onions
# Pizza with: onions, pepperoni, cheddar, thin crust
# Pizza with: onions, pepperoni, cheddar, thick crust
# Pizza with: onions, pepperoni, cheddar, tomato sauce
# Pizza with: onions, pepperoni, cheddar, white sauce
# Pizza with: onions, pepperoni, cheddar, mozzarella
# Pizza with: onions, pepperoni, cheddar, cheddar
# Pizza with: onions, pepperoni, cheddar, pepperoni
# Pizza with: onions, pepperoni, cheddar, mushrooms
# Pizza with: onions, pepperoni, cheddar, onions
# Pizza with: onions, pepperoni, pepperoni, thin crust
# Pizza with: onions, pepperoni, pepperoni, thick crust
# Pizza with: onions, pepperoni, pepperoni, tomato sauce
# Pizza with: onions, pepperoni, pepperoni, white sauce
# Pizza with: onions, pepperoni, pepperoni, mozzarella
# Pizza with: onions, pepperoni, pepperoni, cheddar
# Pizza with: onions, pepperoni, pepperoni, pepperoni
# Pizza with: onions, pepperoni, pepperoni, mushrooms
# Pizza with: onions, pepperoni, pepperoni, onions
# Pizza with: onions, pepperoni, mushrooms, thin crust
# Pizza with: onions, pepperoni, mushrooms, thick crust
# Pizza with: onions, pepperoni, mushrooms, tomato sauce
# Pizza with: onions, pepperoni, mushrooms, white sauce
# Pizza with: onions, pepperoni, mushrooms, mozzarella
# Pizza with: onions, pepperoni, mushrooms, cheddar
# Pizza with: onions, pepperoni, mushrooms, pepperoni
# Pizza with: onions, pepperoni, mushrooms, mushrooms
# Pizza with: onions, pepperoni, mushrooms, onions
# Pizza with: onions, pepperoni, onions, thin crust
# Pizza with: onions, pepperoni, onions, thick crust
# Pizza with: onions, pepperoni, onions, tomato sauce
# Pizza with: onions, pepperoni, onions, white sauce
# Pizza with: onions, pepperoni, onions, mozzarella
# Pizza with: onions, pepperoni, onions, cheddar
# Pizza with: onions, pepperoni, onions, pepperoni
# Pizza with: onions, pepperoni, onions, mushrooms
# Pizza with: onions, pepperoni, onions, onions
# Pizza with: onions, mushrooms, thin crust, thin crust
# Pizza with: onions, mushrooms, thin crust, thick crust
# Pizza with: onions, mushrooms, thin crust, tomato sauce
# Pizza with: onions, mushrooms, thin crust, white sauce
# Pizza with: onions, mushrooms, thin crust, mozzarella
# Pizza with: onions, mushrooms, thin crust, cheddar
# Pizza with: onions, mushrooms, thin crust, pepperoni
# Pizza with: onions, mushrooms, thin crust, mushrooms
# Pizza with: onions, mushrooms, thin crust, onions
# Pizza with: onions, mushrooms, thick crust, thin crust
# Pizza with: onions, mushrooms, thick crust, thick crust
# Pizza with: onions, mushrooms, thick crust, tomato sauce
# Pizza with: onions, mushrooms, thick crust, white sauce
# Pizza with: onions, mushrooms, thick crust, mozzarella
# Pizza with: onions, mushrooms, thick crust, cheddar
# Pizza with: onions, mushrooms, thick crust, pepperoni
# Pizza with: onions, mushrooms, thick crust, mushrooms
# Pizza with: onions, mushrooms, thick crust, onions
# Pizza with: onions, mushrooms, tomato sauce, thin crust
# Pizza with: onions, mushrooms, tomato sauce, thick crust
# Pizza with: onions, mushrooms, tomato sauce, tomato sauce
# Pizza with: onions, mushrooms, tomato sauce, white sauce
# Pizza with: onions, mushrooms, tomato sauce, mozzarella
# Pizza with: onions, mushrooms, tomato sauce, cheddar
# Pizza with: onions, mushrooms, tomato sauce, pepperoni
# Pizza with: onions, mushrooms, tomato sauce, mushrooms
# Pizza with: onions, mushrooms, tomato sauce, onions
# Pizza with: onions, mushrooms, white sauce, thin crust
# Pizza with: onions, mushrooms, white sauce, thick crust
# Pizza with: onions, mushrooms, white sauce, tomato sauce
# Pizza with: onions, mushrooms, white sauce, white sauce
# Pizza with: onions, mushrooms, white sauce, mozzarella
# Pizza with: onions, mushrooms, white sauce, cheddar
# Pizza with: onions, mushrooms, white sauce, pepperoni
# Pizza with: onions, mushrooms, white sauce, mushrooms
# Pizza with: onions, mushrooms, white sauce, onions
# Pizza with: onions, mushrooms, mozzarella, thin crust
# Pizza with: onions, mushrooms, mozzarella, thick crust
# Pizza with: onions, mushrooms, mozzarella, tomato sauce
# Pizza with: onions, mushrooms, mozzarella, white sauce
# Pizza with: onions, mushrooms, mozzarella, mozzarella
# Pizza with: onions, mushrooms, mozzarella, cheddar
# Pizza with: onions, mushrooms, mozzarella, pepperoni
# Pizza with: onions, mushrooms, mozzarella, mushrooms
# Pizza with: onions, mushrooms, mozzarella, onions
# Pizza with: onions, mushrooms, cheddar, thin crust
# Pizza with: onions, mushrooms, cheddar, thick crust
# Pizza with: onions, mushrooms, cheddar, tomato sauce
# Pizza with: onions, mushrooms, cheddar, white sauce
# Pizza with: onions, mushrooms, cheddar, mozzarella
# Pizza with: onions, mushrooms, cheddar, cheddar
# Pizza with: onions, mushrooms, cheddar, pepperoni
# Pizza with: onions, mushrooms, cheddar, mushrooms
# Pizza with: onions, mushrooms, cheddar, onions
# Pizza with: onions, mushrooms, pepperoni, thin crust
# Pizza with: onions, mushrooms, pepperoni, thick crust
# Pizza with: onions, mushrooms, pepperoni, tomato sauce
# Pizza with: onions, mushrooms, pepperoni, white sauce
# Pizza with: onions, mushrooms, pepperoni, mozzarella
# Pizza with: onions, mushrooms, pepperoni, cheddar
# Pizza with: onions, mushrooms, pepperoni, pepperoni
# Pizza with: onions, mushrooms, pepperoni, mushrooms
# Pizza with: onions, mushrooms, pepperoni, onions
# Pizza with: onions, mushrooms, mushrooms, thin crust
# Pizza with: onions, mushrooms, mushrooms, thick crust
# Pizza with: onions, mushrooms, mushrooms, tomato sauce
# Pizza with: onions, mushrooms, mushrooms, white sauce
# Pizza with: onions, mushrooms, mushrooms, mozzarella
# Pizza with: onions, mushrooms, mushrooms, cheddar
# Pizza with: onions, mushrooms, mushrooms, pepperoni
# Pizza with: onions, mushrooms, mushrooms, mushrooms
# Pizza with: onions, mushrooms, mushrooms, onions
# Pizza with: onions, mushrooms, onions, thin crust
# Pizza with: onions, mushrooms, onions, thick crust
# Pizza with: onions, mushrooms, onions, tomato sauce
# Pizza with: onions, mushrooms, onions, white sauce
# Pizza with: onions, mushrooms, onions, mozzarella
# Pizza with: onions, mushrooms, onions, cheddar
# Pizza with: onions, mushrooms, onions, pepperoni
# Pizza with: onions, mushrooms, onions, mushrooms
# Pizza with: onions, mushrooms, onions, onions
# Pizza with: onions, onions, thin crust, thin crust
# Pizza with: onions, onions, thin crust, thick crust
# Pizza with: onions, onions, thin crust, tomato sauce
# Pizza with: onions, onions, thin crust, white sauce
# Pizza with: onions, onions, thin crust, mozzarella
# Pizza with: onions, onions, thin crust, cheddar
# Pizza with: onions, onions, thin crust, pepperoni
# Pizza with: onions, onions, thin crust, mushrooms
# Pizza with: onions, onions, thin crust, onions
# Pizza with: onions, onions, thick crust, thin crust
# Pizza with: onions, onions, thick crust, thick crust
# Pizza with: onions, onions, thick crust, tomato sauce
# Pizza with: onions, onions, thick crust, white sauce
# Pizza with: onions, onions, thick crust, mozzarella
# Pizza with: onions, onions, thick crust, cheddar
# Pizza with: onions, onions, thick crust, pepperoni
# Pizza with: onions, onions, thick crust, mushrooms
# Pizza with: onions, onions, thick crust, onions
# Pizza with: onions, onions, tomato sauce, thin crust
# Pizza with: onions, onions, tomato sauce, thick crust
# Pizza with: onions, onions, tomato sauce, tomato sauce
# Pizza with: onions, onions, tomato sauce, white sauce
# Pizza with: onions, onions, tomato sauce, mozzarella
# Pizza with: onions, onions, tomato sauce, cheddar
# Pizza with: onions, onions, tomato sauce, pepperoni
# Pizza with: onions, onions, tomato sauce, mushrooms
# Pizza with: onions, onions, tomato sauce, onions
# Pizza with: onions, onions, white sauce, thin crust
# Pizza with: onions, onions, white sauce, thick crust
# Pizza with: onions, onions, white sauce, tomato sauce
# Pizza with: onions, onions, white sauce, white sauce
# Pizza with: onions, onions, white sauce, mozzarella
# Pizza with: onions, onions, white sauce, cheddar
# Pizza with: onions, onions, white sauce, pepperoni
# Pizza with: onions, onions, white sauce, mushrooms
# Pizza with: onions, onions, white sauce, onions
# Pizza with: onions, onions, mozzarella, thin crust
# Pizza with: onions, onions, mozzarella, thick crust
# Pizza with: onions, onions, mozzarella, tomato sauce
# Pizza with: onions, onions, mozzarella, white sauce
# Pizza with: onions, onions, mozzarella, mozzarella
# Pizza with: onions, onions, mozzarella, cheddar
# Pizza with: onions, onions, mozzarella, pepperoni
# Pizza with: onions, onions, mozzarella, mushrooms
# Pizza with: onions, onions, mozzarella, onions
# Pizza with: onions, onions, cheddar, thin crust
# Pizza with: onions, onions, cheddar, thick crust
# Pizza with: onions, onions, cheddar, tomato sauce
# Pizza with: onions, onions, cheddar, white sauce
# Pizza with: onions, onions, cheddar, mozzarella
# Pizza with: onions, onions, cheddar, cheddar
# Pizza with: onions, onions, cheddar, pepperoni
# Pizza with: onions, onions, cheddar, mushrooms
# Pizza with: onions, onions, cheddar, onions
# Pizza with: onions, onions, pepperoni, thin crust
# Pizza with: onions, onions, pepperoni, thick crust
# Pizza with: onions, onions, pepperoni, tomato sauce
# Pizza with: onions, onions, pepperoni, white sauce
# Pizza with: onions, onions, pepperoni, mozzarella
# Pizza with: onions, onions, pepperoni, cheddar
# Pizza with: onions, onions, pepperoni, pepperoni
# Pizza with: onions, onions, pepperoni, mushrooms
# Pizza with: onions, onions, pepperoni, onions
# Pizza with: onions, onions, mushrooms, thin crust
# Pizza with: onions, onions, mushrooms, thick crust
# Pizza with: onions, onions, mushrooms, tomato sauce
# Pizza with: onions, onions, mushrooms, white sauce
# Pizza with: onions, onions, mushrooms, mozzarella
# Pizza with: onions, onions, mushrooms, cheddar
# Pizza with: onions, onions, mushrooms, pepperoni
# Pizza with: onions, onions, mushrooms, mushrooms
# Pizza with: onions, onions, mushrooms, onions
# Pizza with: onions, onions, onions, thin crust
# Pizza with: onions, onions, onions, thick crust
# Pizza with: onions, onions, onions, tomato sauce
# Pizza with: onions, onions, onions, white sauce
# Pizza with: onions, onions, onions, mozzarella
# Pizza with: onions, onions, onions, cheddar
# Pizza with: onions, onions, onions, pepperoni
# Pizza with: onions, onions, onions, mushrooms
# Pizza with: onions, onions, onions, onions
# Algorithm 10 times took 11.39 milliseconds

# %% [markdown]
# ## 56. Compare execution times of tow version (1D analysis) - Kayden Le
#
# An online game collects data about each player’s performance in the game. A program is used to analyze the data to make predictions about how players will perform in a new version of the game.
#
# The procedure GetPrediction (idNum) returns a predicted score for the player with ID number idNum. Assume that all predicted scores are positive. The GetPrediction procedure takes approximately 1 minute to return a result. All other operations happen nearly instantaneously.
#
# Two versions of the program are shown below.
#
# Which of the following best compares the execution times of the two versions of the program?
#
# Version I calls the GetPrediction procedure once for each element of idList, or four times total. Since each call requires 1 minute of execution time, version I requires approximately 4 minutes to execute. Version II calls the GetPrediction procedure twice for each element of idList, and then again in the final display statement. This results in the procedure being called nine times, requiring approximately 9 minutes of execution time.
#
# Both versions aim to achieve the same result, which is to find and display the highest predicted score among the players in idList. However, Version I directly updates the highest score (topScore), while Version II updates the ID of the player with the highest score (topID) and then retrieves the predicted score for that player. Version II essentially avoids calling GetPrediction multiple times for the same ID.
#
# The answer: D - Version II requires approximately 5 more minutes to execute than version I

# %%
# Simulate the time taken by GetPrediction, calling an expensive operation twice is slow
# as a popcorn hack (coding challenge)
#  measure the time to calulate fibonacci sequence at small and large numbers
# `this task will require a code layout and a time measurement
#  there are fast ways and slow ways to calculate fibonacci sequence`

'''
The GetPrediction function is a simulation stand-in for a potentially expensive operation.
In a real-world scenario, this could be a call to a;
   - machine learning model
   - a database query
   - fibonacci sequence at a large number
   - or any other algorithm that takes a significant amount of time.
'''
def GetPrediction(idNum):
    # time.sleep(60)  # Commented out to avoid actual delay
    return idNum * 10  # Dummy prediction

# Version I: makes a single call to GetPrediction for each element in idList
def version_I(idList):
    start = time.time()  # Start timer
    topScore = 0
    for idNum in idList:
        predictedScore = GetPrediction(idNum) # calls GetPrediction once
        if predictedScore > topScore: 
            topScore = predictedScore # stores the topScore to avoid calling GetPrediction again
    end = time.time()  # End timer
    print(f"Version I took {end - start + len(idList) * 60:.2f} simulated seconds")  # Add simulated delay

# Version II: makes two calls to GetPrediction for each element in idList
def version_II(idList):
    start = time.time()  # Start timer
    topID = idList[0]
    for idNum in idList:
        if GetPrediction(idNum) > GetPrediction(topID): # calls GetPrediction twice
            topID = idNum # stores the topID, but still calls GetPrediction with topID again
    end = time.time()  # End timer
    print(f"Version II took {end - start + len(idList) * 2 * 60 + 60:.2f} simulated seconds")  # Add simulated delay

# Test the functions
idList = [1, 2, 3, 4] # Small list
# idList = [i for i in range(1, 1000)] # Large list using list comprehension
version_I(idList)
version_II(idList)
# Out:
# Version I took 240.00 simulated seconds
# Version II took 540.00 simulated seconds

# %% [markdown]
# ## 64. Error with multiplication using repeated addition (4C algorithms and programs) - Abdullah Khanani
#
# The following procedure is intended to return the value of x times y, where x and y are integers. Multiplication is implemented using repeated additions.
#
# For which of the following procedure calls does the procedure NOT return the intended value?
#
# Select two answers.

# %% [markdown]
# ### Question 64
#
# PROCEDURE Multiply [x,y]
#     count <-- 0
#     result <-- 0
#     REPEAT UNTIL [count ≥ y]
#         result <-- result + x
#         count <-- count + 1
#     RETURN result
#
# ### Question
#
# #### For which of the following procedure calls does the procedure NOT return the intended value? Select two answers.
#
# ### Options
#
# A. Multiply 2,5
# B. Multiply 2,-5
# C. Multiply -2,5
# D. Multiply -2,-5
#
# ### Answered
#
# A and C
#
# ### Correct Answer
#
# B and D
#
# ### Explanation
#
# For procedures A, the procedure repeatedly adds 2 to result five times, resulting in the intended product 10. Vice versa for C. IF you want to return the result and get a correct answer, multiplying 2,-5 and -2,-5 will give you the wanted result. The following procedure is intended to return the value of x times y, where x and y are integers. Multiplication is implemented using repeated additions. A and C fit these requirements.

# %%
# flawed multiply function
# as a popcorn hack (coding challenge), fix the multiply function to work with negative numbers

'''
As you can see, the function fails when y is negative,
because the while loop condition count < y is never true in these cases.
'''

def multiply(x, y):
    count = 0
    result = 0
    while count < abs(y):
        result += x
        count += 1
    return result

# Test cases
print(multiply(2, 5))  # Expected output: 10
print(multiply(2, -5))  # Expected output: -10, Actual output: 0
print(multiply(-2, 5))  # Expected output: -10
print(multiply(-2, -5))  # Expected output: 10, Actual output: 0
# Out:
# 10
# 10
# -10
# -10

# %% [markdown]
# ## 65. Call to concat and substring (4B string operations) - Ameer Hussain
#
# A program contains the following procedures for string manipulation.
#
# Which of the following can be used to store the string "jackalope" in the string variable animal ?
#
# Select two answers.

# %% [markdown]
# ### Correct Answer C:
# animal ← Substring(“jackrabbit”, 1, 4) extracts “jack” from “jackrabbit”. animal ← Concat(animal, “a”) appends “a” to “jack”, resulting in “jacka”. animal ← Concat(animal, Substring(“antelope”, 5, 4)) extracts “lope” from “antelope” and appends it to “jacka”, resulting in “jackalope”.
#
# ### Incorrect Answer D:
# animal ← Substring(“jackrabbit”, 1, 4) extracts “jack” from “jackrabbit”. animal ← Concat(animal, “a”) appends “a” to “jack”, resulting in “jacka”. animal ← Concat(Substring(“antelope”, 5, 4), animal) is slightly misleading because it extracts “lope” from “antelope” and should prepend it to “jacka”, but this is incorrect because it would result in “lopejacka”. the operations in Answer D would not result in “jackalope”.
#
# animal ← Substring(“antelope”, 5, 4) would assign the substring “lope” from “antelope” to the variable animal. animal ← Concat(“a”, animal) would then prepend “a” to “lope”, resulting in “alope”. animal ← Concat(Substring(“jackrabbit”, 1, 4), animal) would take the substring “jack” from “jackrabbit” and then concatenate it with “alope” resulting in “jackalope”.
#
# The process outlined in Answer B does indeed result in the string “jackalope”, with the first step isolating “lope” from “antelope”, the second step creating the string “alope” by prepending “a” to “lope”, and the final step creating the correct string by prepending “jack” to “alope”.
#
# animal ← Substring(“antelope”, 5, 4) would assign the substring “lope” from “antelope” to the variable animal. animal ← Concat(“a”, animal) would then prepend “a” to “lope”, resulting in “alope”. animal ← Concat(Substring(“jackrabbit”, 1, 4), animal) would take the substring “jack” from “jackrabbit” and then concatenate it with “alope” resulting in “jackalope”.
#
# The process outlined in Answer B does indeed result in the string “jackalope”, with the first step isolating “lope” from “antelope”, the second step creating the string “alope” by prepending “a” to “lope”, and the final step creating the correct string by prepending “jack” to “alope”.

# %%
# Incorrect Answer D
# as a popcorn hack (binary challenge), create string and concatenation options for A, B, C
 
animal = "jackrabbit"[0:4]  # Substring("jackrabbit", 1, 4)
animal += "a"  # Concat(animal, "a")
animal = animal +"antelope"[4:8]   # Concat(Substring("antelope", 5, 4), animal)
print(animal)  # Outputs: lopejacka
# Out:
# jackalope

# %%
def concat(str1, str2):
    return str1 + str2

def substring(string, start, length):
    return string[start - 1:start - 1 + length]
# 
animal = substring("antelope", 5, 4)

animal = concat("a", animal)
print(animal)  # "alope"

animal = concat(substring("jackrabbit", 1, 4), animal)


# 
animal = substring("jackrabbit", 1, 4)

animal = concat(animal, "a")

animal = concat(animal, substring("antelope", 5, 4))
print(animal)  # "jackalope"

# 
animal = substring("jackrabbit", 1, 4)
animal = concat(animal, "a")
animal = concat(substring("antelope", 5, 4), animal)
print(animal)  # "alopejacka"
# Out:
# alope
# jackalope
# lopejacka
